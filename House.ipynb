# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Housing.csv')

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
numeric_columns = ['price','area','bedrooms','bathrooms','stories','parking']
for col in numeric_columns:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col],kde = True,bins = 20)

# %%
sns.countplot(x = df['mainroad'])
# Out:
# <Axes: xlabel='mainroad', ylabel='count'>

# %%
sns.countplot(x = df['guestroom'])
# Out:
# <Axes: xlabel='guestroom', ylabel='count'>

# %%
sns.countplot(x = df['basement'])
# Out:
# <Axes: xlabel='basement', ylabel='count'>

# %%
sns.countplot(x = df['hotwaterheating'])
# Out:
# <Axes: xlabel='hotwaterheating', ylabel='count'>

# %%
sns.countplot(x = df['airconditioning'])
# Out:
# <Axes: xlabel='airconditioning', ylabel='count'>

# %%
sns.countplot(x = df['prefarea'])
# Out:
# <Axes: xlabel='prefarea', ylabel='count'>

# %%
sns.countplot(x = df['furnishingstatus'])
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %%
for col in numeric_columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(x = df[col])

# %%
corr = df[numeric_columns].corr()
corr
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.535997  0.366494   0.517545  0.420712  0.384394
# area       0.535997  1.000000  0.151858   0.193820  0.083996  0.352980
# bedrooms   0.366494  0.151858  1.000000   0.373930  0.408564  0.139270
# bathrooms  0.517545  0.193820  0.373930   1.000000  0.326165  0.177496
# stories    0.420712  0.083996  0.408564   0.326165  1.000000  0.045547
# parking    0.384394  0.352980  0.139270   0.177496  0.045547  1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only = True),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## data cleaning and preprocessing

# %%
df_cleaned = df.copy()

# %%
df_cleaned
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df_cleaned.shape
# Out:
# (545, 13)

# %%
df_cleaned.drop_duplicates(inplace=True)

# %%
df_cleaned.shape
# Out:
# (545, 13)

# %%
df_cleaned.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %% [markdown]
# ### now will do label encoding and convert all the categories with binary data

# %%
df_cleaned['mainroad'].value_counts()
# Out:
# mainroad
# yes    468
# no      77
# Name: count, dtype: int64

# %%
df_cleaned['mainroad'] = df_cleaned['mainroad'].replace({"yes":1,"no":0})

# %%
df_cleaned.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories  mainroad guestroom basement  \
# 540  1820000  3000         2          1        1         1        no      yes
# 541  1767150  2400         3          1        1         0        no       no
# 542  1750000  3620         2          1        1         1        no       no
# 543  1750000  2910         3          1        1         0        no       no
# 544  1750000  3850         3          1        2         1        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
df_cleaned['guestroom'].value_counts()
# Out:
# guestroom
# no     448
# yes     97
# Name: count, dtype: int64

# %%
df_cleaned['guestroom'] = df_cleaned['guestroom'].replace({"yes":1,"no":0})

# %%
df_cleaned.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom basement  \
# 0  13300000  7420         4          2        3         1          0       no
# 1  12250000  8960         4          4        4         1          0       no
# 2  12250000  9960         3          2        2         1          0      yes
# 3  12215000  7500         4          2        2         1          0      yes
# 4  11410000  7420         4          1        2         1          1      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df_cleaned['basement'].value_counts()
# Out:
# basement
# no     354
# yes    191
# Name: count, dtype: int64

# %%
df_cleaned['basement'] = df_cleaned['basement'].replace({"yes":1,"no":0})

# %%
df_cleaned.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0         0              no             yes        2      yes        furnished
# 1         0              no             yes        3       no        furnished
# 2         1              no              no        2      yes   semi-furnished
# 3         1              no             yes        3      yes        furnished
# 4         1              no             yes        2       no        furnished

# %%
df_cleaned['hotwaterheating'].value_counts()
# Out:
# hotwaterheating
# no     520
# yes     25
# Name: count, dtype: int64

# %%
df_cleaned['hotwaterheating'] = df_cleaned['hotwaterheating'].replace({"yes":1,"no":0})

# %%
df_cleaned.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating airconditioning  parking prefarea  \
# 0         0                0             yes        2      yes
# 1         0                0             yes        3       no
# 2         1                0              no        2      yes
# 3         1                0             yes        3      yes
# 4         1                0             yes        2       no
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
df_cleaned['airconditioning'].value_counts()
# Out:
# airconditioning
# no     373
# yes    172
# Name: count, dtype: int64

# %%
df_cleaned['airconditioning'] = df_cleaned['airconditioning'].replace({"yes":1,"no":0})

# %%
df_cleaned.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking prefarea  \
# 0         0                0                1        2      yes
# 1         0                0                1        3       no
# 2         1                0                0        2      yes
# 3         1                0                1        3      yes
# 4         1                0                1        2       no
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
df_cleaned['parking'].value_counts()
# Out:
# parking
# 0    299
# 1    126
# 2    108
# 3     12
# Name: count, dtype: int64

# %%
df_cleaned['prefarea'].value_counts()
# Out:
# prefarea
# no     417
# yes    128
# Name: count, dtype: int64

# %%
df_cleaned['prefarea'] = df_cleaned['prefarea'].replace({"yes":1,"no":0})

# %%
df_cleaned.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %% [markdown]
# #### since the furnishingstatus has 3 values we will perform one-hot encoding here

# %%
df_cleaned['furnishingstatus'].value_counts()
# Out:
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64

# %%
df_cleaned = pd.get_dummies(df_cleaned,columns = ['furnishingstatus'],drop_first = True)

# %%
df_cleaned.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# 0                            False                         False
# ...

# %%
df_cleaned = df_cleaned.astype(int)

# %%
df_cleaned
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...
